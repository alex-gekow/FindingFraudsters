# %%
import xgboost as xgb
import numpy as np
import pandas as pd
import glob
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.preprocessing import StandardScaler
import time
import optuna
import matplotlib.pyplot as plt

# %%
data_path = "/data/rjoshi/erdos/"

# %%
files = glob.glob(f"{data_path}/*.csv")
files = [f for f in files if "sample_submission" not in f]

# %%
df_test_transaction = pd.read_csv(files[0])
df_train_transaction = pd.read_csv(files[3])

# %%
cols_to_use = ['card1', 'V304', 'V123', 'card3', 'V34', 'V74', 'V94', 'V52', 'V257', 'isFraud']

# %%
df_train_to_use = df_train_transaction[cols_to_use]
df_train_to_use = df_train_to_use.fillna(-999)
sample_weights = compute_sample_weight(class_weight="balanced", y=df_train_to_use['isFraud'])

# %%
split_index1 = int(df_train_to_use.shape[0]*0.8)
split_index2 = int(df_train_to_use.shape[0]*0.9)
train_df, val_df, test_df = df_train_to_use[:split_index1], df_train_to_use[split_index1:split_index2], df_train_to_use[split_index2:]
sample_weights_train, sample_weights_val = sample_weights[:split_index1], sample_weights[split_index1:split_index2]
y_train  = train_df.pop('isFraud')
y_test = test_df.pop('isFraud')
y_val = val_df.pop('isFraud')
x_train = train_df
x_test = test_df
x_val = val_df

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
#skf = StratifiedKFold()
model = xgb.XGBClassifier(callbacks = [xgb.callback.EarlyStopping(3)], random_state = 42)
#for i, (train_index, val_index) in enumerate(skf.split()):
model.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_val,y_val)])
# Out:
# [0]	validation_0-logloss:0.17643	validation_1-logloss:0.17091
# [1]	validation_0-logloss:0.15714	validation_1-logloss:0.15176
# [2]	validation_0-logloss:0.14399	validation_1-logloss:0.13920
# [3]	validation_0-logloss:0.13579	validation_1-logloss:0.13090
# [4]	validation_0-logloss:0.13026	validation_1-logloss:0.12546
# [5]	validation_0-logloss:0.12680	validation_1-logloss:0.12192
# [6]	validation_0-logloss:0.12466	validation_1-logloss:0.11981
# [7]	validation_0-logloss:0.12304	validation_1-logloss:0.11861
# [8]	validation_0-logloss:0.12212	validation_1-logloss:0.11775
# [9]	validation_0-logloss:0.12123	validation_1-logloss:0.11715
# [10]	validation_0-logloss:0.12075	validation_1-logloss:0.11688
# [11]	validation_0-logloss:0.12002	validation_1-logloss:0.11691
# [12]	validation_0-logloss:0.11961	validation_1-logloss:0.11666
# [13]	validation_0-logloss:0.11947	validation_1-logloss:0.11662
# [14]	validation_0-logloss:0.11887	validation_1-logloss:0.11636
# [15]	validation_0-logloss:0.11869	validation_1-logloss:0.11629
# [16]	validation_0-logloss:0.11801	validation_1-logloss:0.11577
# [17]	validation_0-logloss:0.11791	validation_1-logloss:0.11578
# [18]	validation_0-logloss:0.11759	validation_1-logloss:0.11578
# [19]	validation_0-logloss:0.11741	validation_1-logloss:0.11570
# [20]	validation_0-logloss:0.11724	validation_1-logloss:0.11562
# [21]	validation_0-logloss:0.11680	validation_1-logloss:0.11556
# [22]	validation_0-logloss:0.11667	validation_1-logloss:0.11550
# [23]	validation_0-logloss:0.11636	validation_1-logloss:0.11546
# [24]	validation_0-logloss:0.11616	validation_1-logloss:0.11542
# [25]	validation_0-logloss:0.11609	validation_1-logloss:0.11536
# [26]	validation_0-logloss:0.11582	validation_1-logloss:0.11510
# [27]	validation_0-logloss:0.11567	validation_1-logloss:0.11511
# [28]	validation_0-logloss:0.11562	validation_1-logloss:0.11511
# [29]	validation_0-logloss:0.11544	validation_1-logloss:0.11509
# [30]	validation_0-logloss:0.11540	validation_1-logloss:0.11508
# [31]	validation_0-logloss:0.11528	validation_1-logloss:0.11504
# [32]	validation_0-logloss:0.11515	validation_1-logloss:0.11504
# [33]	validation_0-logloss:0.11503	validation_1-logloss:0.11496
# [34]	validation_0-logloss:0.11500	validation_1-logloss:0.11495
# [35]	validation_0-logloss:0.11492	validation_1-logloss:0.11496
# [36]	validation_0-logloss:0.11477	validation_1-logloss:0.11504
# [37]	validation_0-logloss:0.11473	validation_1-logloss:0.11507
# XGBClassifier(base_score=None, booster=None,
#               callbacks=[<xgboost.callback.EarlyStopping object at 0x7f4d577fc2e0>],
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_train = model.predict(x_train)
y_pred_val = model.predict(x_val)
print(metrics.classification_report(y_train, y_pred_train, target_names=["Not Fraud", "Fraud"]))
print(metrics.classification_report(y_val, y_pred_val, target_names=["Not Fraud", "Fraud"]))
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_pred_val)
print(metrics.auc(fpr, tpr))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      1.00      0.99    455833
#        Fraud       0.83      0.22      0.35     16599
#
#     accuracy                           0.97    472432
#    macro avg       0.90      0.61      0.67    472432
# weighted avg       0.97      0.97      0.96    472432
#
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      1.00      0.99     57203
#        Fraud       0.69      0.17      0.27      1851
#
#     accuracy                           0.97     59054
#    macro avg       0.83      0.58      0.63     59054
# weighted avg       0.96      0.97      0.96     59054
#
# 0.5825148076759961

# %%
# Hyper-parameter optimization
def optuna_objective(trial, x_train, y_train, sample_weights, x_validation, y_validation, sample_weights_val = None, metric='f1'):
    metric = metric.lower()
    params = {
       'tree_method': 'hist',
       'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.6, 1.0),
        'lambda': trial.suggest_float('lambda', 0.001, 25, log=True),
        'reg_alpha': trial.suggest_float('alpha', 0, 25),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.8),
        'objective': 'binary:logistic',
        'eval_metric': ['logloss', 'auc', 'aucpr'],
        'n_estimators': trial.suggest_int('n_estimators', 40, 100),
        'max_delta_step': trial.suggest_float('max_delta_step', 1, 9),
        'early_stopping_rounds': 5
    }

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'validation_1-logloss')
    bdt_model = xgb.XGBClassifier(**params, callbacks=[pruning_callback])
    bdt_model.fit(x_train, y_train, sample_weight=sample_weights, eval_set=[(x_train, y_train), (x_validation,y_validation)], 
                  sample_weight_eval_set=[sample_weights, sample_weights_val])
    
    y_pred_val =  bdt_model.predict(x_validation)
    #f1Score = metrics.f1_score(y_validation, y_pred_val, average="weighted", sample_weight = sample_weights_val)
    f1Score = metrics.f1_score(y_validation, y_pred_val)
    print(f1Score)
    return f1Score

def hyper_parameter_optimization(x_train, y_train, x_validation, y_validation, sample_weights = None, sample_weights_val=None, metric='f1', 
                                    ntrials = 50):
    sampler = optuna.samplers.TPESampler(seed=123)
    #sampler = optuna.samplers.QMCSampler(seed=123)
    pruner = optuna.pruners.HyperbandPruner()
    study = optuna.create_study(direction='maximize', sampler=sampler, pruner=pruner)
    study.optimize(lambda trial: optuna_objective(trial, x_train, y_train, sample_weights, x_validation, y_validation, sample_weights_val, 
                                                  metric=metric), n_trials = ntrials)
    best_params = study.best_params
    return best_params

# %%
hyper_parameter_optimization(x_train, y_train, x_val, y_val, sample_weights = sample_weights_train)

# %%
# Best parameters based on f1 score of validation set
best_params = {'max_depth': 9,
 'subsample': 0.8893665432759819,
 'colsample_bynode': 0.6064516826780068,
 'lambda': 0.41141085381708425,
 'alpha': 13.919629809857218,
 'learning_rate': 0.12800875567163347,
 'n_estimators': 49,
 'max_delta_step': 6.564236230167287}

# %%
df_cv_train = df_train_to_use[:split_index2]
y_cv_train = df_cv_train.pop('isFraud')
x_cv_train = df_cv_train
sample_weights_cv = sample_weights[:split_index2]
del df_cv_train

# %%
skf = StratifiedKFold()
model = xgb.XGBClassifier(callbacks = [xgb.callback.EarlyStopping(3)], random_state = 42, eval_metric =['logloss', 'auc', 'aucpr'],
                          **best_params)
for i, (train_index, val_index) in enumerate(skf.split(x_cv_train, y_cv_train)):
    print(f"-------------------------- \nFold {i}\n----------------------------")
    x_train_fold, x_val_fold = x_cv_train.iloc[train_index], x_cv_train.iloc[val_index]
    y_train_fold, y_val_fold = y_cv_train.iloc[train_index], y_cv_train.iloc[val_index]
    sample_weights_fold = sample_weights_cv[train_index]
    model.fit(x_train_fold, y_train_fold, sample_weight=sample_weights_fold, eval_set=[(x_train_fold, y_train_fold), (x_val_fold, y_val_fold)])
# Out:
# --------------------------
# Fold 0
# ----------------------------
# [0]	validation_0-logloss:0.66177	validation_0-auc:0.74197	validation_0-aucpr:0.30775	validation_1-logloss:0.67604	validation_1-auc:0.65109	validation_1-aucpr:0.20918
# [1]	validation_0-logloss:0.63697	validation_0-auc:0.75859	validation_0-aucpr:0.33272	validation_1-logloss:0.66045	validation_1-auc:0.66781	validation_1-aucpr:0.23716
# [2]	validation_0-logloss:0.61743	validation_0-auc:0.76358	validation_0-aucpr:0.33695	validation_1-logloss:0.64989	validation_1-auc:0.67344	validation_1-aucpr:0.23983
# [3]	validation_0-logloss:0.60010	validation_0-auc:0.76979	validation_0-aucpr:0.34275	validation_1-logloss:0.64024	validation_1-auc:0.68029	validation_1-aucpr:0.24604
# [4]	validation_0-logloss:0.58603	validation_0-auc:0.77225	validation_0-aucpr:0.34476	validation_1-logloss:0.63226	validation_1-auc:0.68263	validation_1-aucpr:0.24935
# [5]	validation_0-logloss:0.57374	validation_0-auc:0.77297	validation_0-aucpr:0.34811	validation_1-logloss:0.62593	validation_1-auc:0.68250	validation_1-aucpr:0.25193
# [6]	validation_0-logloss:0.56347	validation_0-auc:0.77498	validation_0-aucpr:0.35102	validation_1-logloss:0.61936	validation_1-auc:0.67951	validation_1-aucpr:0.25221
# [7]	validation_0-logloss:0.55444	validation_0-auc:0.77697	validation_0-aucpr:0.35163	validation_1-logloss:0.61442	validation_1-auc:0.68313	validation_1-aucpr:0.24434
# [8]	validation_0-logloss:0.54683	validation_0-auc:0.78171	validation_0-aucpr:0.35230	validation_1-logloss:0.61023	validation_1-auc:0.68301	validation_1-aucpr:0.24556
# [9]	validation_0-logloss:0.54026	validation_0-auc:0.78228	validation_0-aucpr:0.35389	validation_1-logloss:0.60751	validation_1-auc:0.68258	validation_1-aucpr:0.24481
# --------------------------
# Fold 1
# ----------------------------
# [0]	validation_0-logloss:0.66209	validation_0-auc:0.74250	validation_0-aucpr:0.31329	validation_1-logloss:0.66154	validation_1-auc:0.71213	validation_1-aucpr:0.29541
# [1]	validation_0-logloss:0.63889	validation_0-auc:0.75066	validation_0-aucpr:0.32171	validation_1-logloss:0.63799	validation_1-auc:0.71232	validation_1-aucpr:0.29637
# [2]	validation_0-logloss:0.62022	validation_0-auc:0.75085	validation_0-aucpr:0.32287	validation_1-logloss:0.61881	validation_1-auc:0.71261	validation_1-aucpr:0.29696
# [3]	validation_0-logloss:0.60332	validation_0-auc:0.75430	validation_0-aucpr:0.32962	validation_1-logloss:0.60163	validation_1-auc:0.71586	validation_1-aucpr:0.30123
# [4]	validation_0-logloss:0.58922	validation_0-auc:0.75720	validation_0-aucpr:0.33322	validation_1-logloss:0.58743	validation_1-auc:0.71870	validation_1-aucpr:0.30226
# [5]	validation_0-logloss:0.57778	validation_0-auc:0.75737	validation_0-aucpr:0.33475	validation_1-logloss:0.57580	validation_1-auc:0.71937	validation_1-aucpr:0.30673
# [6]	validation_0-logloss:0.56738	validation_0-auc:0.76484	validation_0-aucpr:0.33769	validation_1-logloss:0.56485	validation_1-auc:0.72726	validation_1-aucpr:0.30977
# [7]	validation_0-logloss:0.55907	validation_0-auc:0.76513	validation_0-aucpr:0.33846	validation_1-logloss:0.55644	validation_1-auc:0.72826	validation_1-aucpr:0.31058
# [8]	validation_0-logloss:0.55194	validation_0-auc:0.76850	validation_0-aucpr:0.33984	validation_1-logloss:0.54950	validation_1-auc:0.72882	validation_1-aucpr:0.31250
# [9]	validation_0-logloss:0.54513	validation_0-auc:0.77209	validation_0-aucpr:0.34177	validation_1-logloss:0.54272	validation_1-auc:0.73380	validation_1-aucpr:0.31337
# [10]	validation_0-logloss:0.53992	validation_0-auc:0.77359	validation_0-aucpr:0.34241	validation_1-logloss:0.53744	validation_1-auc:0.73680	validation_1-aucpr:0.31395
# [11]	validation_0-logloss:0.53548	validation_0-auc:0.77438	validation_0-aucpr:0.34333	validation_1-logloss:0.53316	validation_1-auc:0.73753	validation_1-aucpr:0.31495
# [12]	validation_0-logloss:0.53121	validation_0-auc:0.77503	validation_0-aucpr:0.34443	validation_1-logloss:0.52870	validation_1-auc:0.73665	validation_1-aucpr:0.31514
# [13]	validation_0-logloss:0.52704	validation_0-auc:0.77697	validation_0-aucpr:0.34642	validation_1-logloss:0.52459	validation_1-auc:0.73732	validation_1-aucpr:0.31516
# [14]	validation_0-logloss:0.52365	validation_0-auc:0.77834	validation_0-aucpr:0.34732	validation_1-logloss:0.52117	validation_1-auc:0.73642	validation_1-aucpr:0.31636
# [15]	validation_0-logloss:0.52067	validation_0-auc:0.78118	validation_0-aucpr:0.34872	validation_1-logloss:0.51819	validation_1-auc:0.73892	validation_1-aucpr:0.31718
# [16]	validation_0-logloss:0.51809	validation_0-auc:0.78263	validation_0-aucpr:0.34990	validation_1-logloss:0.51571	validation_1-auc:0.73997	validation_1-aucpr:0.31722
# [17]	validation_0-logloss:0.51571	validation_0-auc:0.78384	validation_0-aucpr:0.35081	validation_1-logloss:0.51328	validation_1-auc:0.74098	validation_1-aucpr:0.31876
# [18]	validation_0-logloss:0.51398	validation_0-auc:0.78583	validation_0-aucpr:0.35157	validation_1-logloss:0.51171	validation_1-auc:0.74178	validation_1-aucpr:0.31885
# [19]	validation_0-logloss:0.51231	validation_0-auc:0.78648	validation_0-aucpr:0.35241	validation_1-logloss:0.50997	validation_1-auc:0.74325	validation_1-aucpr:0.31955
# [20]	validation_0-logloss:0.51001	validation_0-auc:0.79031	validation_0-aucpr:0.35358	validation_1-logloss:0.50779	validation_1-auc:0.74836	validation_1-aucpr:0.32066
# [21]	validation_0-logloss:0.50879	validation_0-auc:0.79049	validation_0-aucpr:0.35458	validation_1-logloss:0.50661	validation_1-auc:0.74835	validation_1-aucpr:0.32112
# [22]	validation_0-logloss:0.50762	validation_0-auc:0.79201	validation_0-aucpr:0.35541	validation_1-logloss:0.50551	validation_1-auc:0.75108	validation_1-aucpr:0.32201
# [23]	validation_0-logloss:0.50685	validation_0-auc:0.79219	validation_0-aucpr:0.35585	validation_1-logloss:0.50477	validation_1-auc:0.75183	validation_1-aucpr:0.32285
# [24]	validation_0-logloss:0.50637	validation_0-auc:0.79226	validation_0-aucpr:0.35606	validation_1-logloss:0.50438	validation_1-auc:0.75186	validation_1-aucpr:0.32264
# [25]	validation_0-logloss:0.50493	validation_0-auc:0.79305	validation_0-aucpr:0.35747	validation_1-logloss:0.50316	validation_1-auc:0.75300	validation_1-aucpr:0.32394
# [26]	validation_0-logloss:0.50395	validation_0-auc:0.79400	validation_0-aucpr:0.35794	validation_1-logloss:0.50243	validation_1-auc:0.75285	validation_1-aucpr:0.32368
# [27]	validation_0-logloss:0.50330	validation_0-auc:0.79455	validation_0-aucpr:0.35850	validation_1-logloss:0.50179	validation_1-auc:0.75358	validation_1-aucpr:0.32444
# [28]	validation_0-logloss:0.50206	validation_0-auc:0.79553	validation_0-aucpr:0.35910	validation_1-logloss:0.50069	validation_1-auc:0.75452	validation_1-aucpr:0.32481
# [29]	validation_0-logloss:0.50174	validation_0-auc:0.79595	validation_0-aucpr:0.35878	validation_1-logloss:0.50047	validation_1-auc:0.75526	validation_1-aucpr:0.32538
# [30]	validation_0-logloss:0.50047	validation_0-auc:0.79775	validation_0-aucpr:0.36031	validation_1-logloss:0.49930	validation_1-auc:0.75493	validation_1-aucpr:0.32562
# [31]	validation_0-logloss:0.49965	validation_0-auc:0.79811	validation_0-aucpr:0.36124	validation_1-logloss:0.49848	validation_1-auc:0.75544	validation_1-aucpr:0.32598
# [32]	validation_0-logloss:0.49859	validation_0-auc:0.79899	validation_0-aucpr:0.36191	validation_1-logloss:0.49776	validation_1-auc:0.75674	validation_1-aucpr:0.32623
# [33]	validation_0-logloss:0.49848	validation_0-auc:0.79901	validation_0-aucpr:0.36194	validation_1-logloss:0.49769	validation_1-auc:0.75674	validation_1-aucpr:0.32616
# [34]	validation_0-logloss:0.49785	validation_0-auc:0.79937	validation_0-aucpr:0.36283	validation_1-logloss:0.49731	validation_1-auc:0.75628	validation_1-aucpr:0.32597
# --------------------------
# Fold 2
# ----------------------------
# [0]	validation_0-logloss:0.66324	validation_0-auc:0.72833	validation_0-aucpr:0.30296	validation_1-logloss:0.66164	validation_1-auc:0.74879	validation_1-aucpr:0.33121
# [1]	validation_0-logloss:0.64120	validation_0-auc:0.73997	validation_0-aucpr:0.30893	validation_1-logloss:0.63809	validation_1-auc:0.75933	validation_1-aucpr:0.32705
# [2]	validation_0-logloss:0.62350	validation_0-auc:0.74427	validation_0-aucpr:0.31341	validation_1-logloss:0.61923	validation_1-auc:0.76834	validation_1-aucpr:0.32841
# [3]	validation_0-logloss:0.60764	validation_0-auc:0.74781	validation_0-aucpr:0.31963	validation_1-logloss:0.60251	validation_1-auc:0.77107	validation_1-aucpr:0.33089
# --------------------------
# Fold 3
# ----------------------------
# --------------------------
# Fold 4
# ----------------------------
# [0]	validation_0-logloss:0.66144	validation_0-auc:0.74692	validation_0-aucpr:0.31087	validation_1-logloss:0.66087	validation_1-auc:0.72326	validation_1-aucpr:0.27320
